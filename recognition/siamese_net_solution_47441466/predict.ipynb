# %%
#after training and saving a model, I can load it here and use it for inference.


#general structure:
    #import image data using the ISICDataset class
    #load a saved model
    #pass image data through the model to get embeddings
    #make predictions based on the embeddings
    #present results
