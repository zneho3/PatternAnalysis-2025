# %%
import os
import random
import pandas as pd
import torch
from torchvision import transforms
from torch.utils.data import Dataset
from PIL import Image


class KaggleISICDataSet(Dataset):
  """
  Class to load the skin dataset for training, testing and validation.
  Uses the locally stored images and the csv file with the labels.
  """
  def __init__():
    """
    Initialise the DataSet object
    Will need to know things like image directory, label CSV etc
    Also needs transforms for preprocessing, which will be passed in from the main notebook.
    Maybe also a flag for if we want to use local files or download from Kaggle.
    If downloading from Kaggle, will need to use the Kaggle API. Can use the kaggle python package.
    """
    pass
    
  def preprocess_imgages(self):
    """"
    Preprocess the images.
    """
    pass
      

def create_data_loaders():
  """
  Create the data loaders for training, validation and testing.
  """
  pass
