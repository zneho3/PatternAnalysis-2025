# %%
#Components of the model architecture
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import math
import numpy as np


##need to check the data dimensions and work out good hyperparameters.
class SiameseNetwork(nn.Module):
    
    """
    Siamese network model block
    We want to use the resnet50 most likely
    """
    def __init__(self):
        pass

    def forward_once(self, x):
        pass
    
    def forward(self, input1, input2):
        pass


class LossFunction(nn.Module):
    """
    Need to decide what type of loss function I will use. Triplet or contrastive. Also consider if we need to change this if the model 
    uses a different backbone model
    
    Make sure i change the name for this later to reflect the actual loss function i use. 
    Or.... i could keep allow user to switch between types of loss function
    Orrr I can just import from pytorch directly - this looks better atm - much less work

    Args:
    """
    def __init__(self):
        pass

    def forward(self, output1, output2, label):
        pass
